# %%
# Fooocus2026 (mikecastrodemaria fork of Fooocus) on Colab
# Colab runs Python 3.13, and the pinned stack (torch 2.1, gradio 3.41, onnxruntime 1.18,
# safetensors 0.4...) has no wheels for it: pip tries to compile scipy and friends from
# source, then fails. uv creates a Python 3.11 venv in a few seconds and the launcher
# installs torch and the requirements into it, as it does on Windows.
# %cd /content
# !git clone https://github.com/mikecastrodemaria/Fooocus2026.git
# %cd /content/Fooocus2026
# !pip install -q uv
# !uv venv --python 3.11 --seed /content/venv
# %env FOOOCUS_AUTO_UPDATE=1
# !/content/venv/bin/python entry_with_update.py --share --always-high-vram
