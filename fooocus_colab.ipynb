# %%
# Fooocus2026 (mikecastrodemaria fork of Fooocus) on Colab
# pygit2 is not needed anymore (the fork's boot update check replaced it, custom-19)
# and does not build on Colab's Python 3.13 anyway.
# %cd /content
# !git clone https://github.com/mikecastrodemaria/Fooocus2026.git
# %cd /content/Fooocus2026
# %env FOOOCUS_AUTO_UPDATE=1
# !python entry_with_update.py --share --always-high-vram
